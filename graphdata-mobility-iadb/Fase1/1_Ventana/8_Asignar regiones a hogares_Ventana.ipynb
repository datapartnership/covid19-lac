# %% [markdown]
# ### Preparar ambiente

# %%
import enum
print(enum.__file__)  
# standard library location should be something like 
# /usr/local/lib/python3.6/enum.py
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/enum.py

# %%
import sys
# !{sys.executable} -m pip uninstall -y enum34
# Out:
# WARNING: Skipping enum34 as it is not installed.

# %%
# !{sys.executable} -m pip install awswrangler
# Out:
# Requirement already satisfied: awswrangler in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.8.0)
# Requirement already satisfied: pandas<1.3.0,>=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.1.5)
# Requirement already satisfied: pg8000<1.20.0,>=1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.19.5)
# Requirement already satisfied: openpyxl~=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (3.0.6)
# Requirement already satisfied: pyarrow<4.1.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (4.0.0)
# Requirement already satisfied: boto3<2.0.0,>=1.12.49 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.17.83)
# Requirement already satisfied: pymysql<1.1.0,>=0.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.0.2)
# Requirement already satisfied: redshift-connector~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (2.0.881)
# Requirement already satisfied: numpy<1.21.0,>=1.18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.19.5)
# Requirement already satisfied: botocore<2.0.0,>=1.15.49 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from awswrangler) (1.20.83)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0.0,>=1.12.49->awswrangler) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0.0,>=1.12.49->awswrangler) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<2.0.0,>=1.15.49->awswrangler) (1.26.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<2.0.0,>=1.15.49->awswrangler) (2.8.1)
# Requirement already satisfied: et-xmlfile in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from openpyxl~=3.0.0->awswrangler) (1.0.1)
# Requirement already satisfied: jdcal in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from openpyxl~=3.0.0->awswrangler) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas<1.3.0,>=1.1.0->awswrangler) (2021.1)
# Requirement already satisfied: scramp==1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pg8000<1.20.0,>=1.16.0->awswrangler) (1.4.0)
# Requirement already satisfied: asn1crypto==1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scramp==1.4.0->pg8000<1.20.0,>=1.16.0->awswrangler) (1.4.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.15.49->awswrangler) (1.15.0)
# Requirement already satisfied: lxml>=4.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from redshift-connector~=2.0.0->awswrangler) (4.6.3)
# Requirement already satisfied: requests<2.25.2,>=2.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from redshift-connector~=2.0.0->awswrangler) (2.25.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from redshift-connector~=2.0.0->awswrangler) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from beautifulsoup4<5.0.0,>=4.7.0->redshift-connector~=2.0.0->awswrangler) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<2.25.2,>=2.23.0->redshift-connector~=2.0.0->awswrangler) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<2.25.2,>=2.23.0->redshift-connector~=2.0.0->awswrangler) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<2.25.2,>=2.23.0->redshift-connector~=2.0.0->awswrangler) (3.0.4)

# %%
# !{sys.executable} -m pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.9.0)
# Requirement already satisfied: shapely>=1.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pyproj>=2.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from geopandas) (3.0.1)
# Requirement already satisfied: pandas>=0.24.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from geopandas) (1.1.5)
# Requirement already satisfied: fiona>=1.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fiona>=1.8->geopandas) (49.6.0.post20210108)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: cligj>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: six>=1.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: attrs>=17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: click>=4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: click-plugins>=1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: munch in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.24.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.15.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.24.0->geopandas) (1.19.5)

# %%
# !{sys.executable} -m pip install PyAthena
# Out:
# Requirement already satisfied: PyAthena in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.3.0)
# Requirement already satisfied: tenacity>=4.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from PyAthena) (7.0.0)
# Requirement already satisfied: boto3>=1.4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from PyAthena) (1.17.83)
# Requirement already satisfied: botocore>=1.5.52 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from PyAthena) (1.20.83)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.4.4->PyAthena) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.4.4->PyAthena) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore>=1.5.52->PyAthena) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore>=1.5.52->PyAthena) (1.26.5)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.5.52->PyAthena) (1.15.0)

# %% [markdown]
# ### Conectar con pyathena

# %%
from pyathena.pandas.cursor import PandasCursor
from pyathena import connect
import pandas as pd
import time
# agregar directorio en el cual se almacenan las tablas que se van a consultar
directorio = 's3://iadbprod-csd-hub-analyticaldata/graphdata-mobility-temporal/athena-results/'
# base de datos
bd = 'graphdata' # Database in Glue
cursor = connect(s3_staging_dir = directorio, region_name = 'us-east-1', schema_name = bd, cursor_class = PandasCursor).cursor()

# %%
import pandas as pd
import awswrangler as wr
import numpy as np
import calendar
import boto3
s3 = boto3.resource('s3')

# %%
import geopandas as gpd
import glob
import os

# %% [markdown]
# ### Verificar que están localmente los archivos Shapefile. Si no están, descargarlos

# %%
if not os.path.exists('Shapefiles'):
    bucket_shapefiles = 'iadbprod-csd-hub-analyticaldata'
    folder_local = 'Shapefiles'
    os.mkdir(folder_local)
    for key in s3.Bucket(bucket_shapefiles).objects.all().filter(Prefix=folder_local):
        data_key = key.key
        directorios = data_key.split('/')
        if len(directorios) == 3 and not 'Municipios' in data_key: # carpeta originen, pais y archivo (shp, cpg, csv, dbf, prj, shx)
            folder_pais = os.path.join(folder_local, directorios[1])
            if not os.path.exists(folder_pais):
                os.mkdir(folder_pais)
            new_data_key = os.path.join(folder_pais,directorios[2])
            s3.Bucket(bucket_shapefiles).download_file(data_key, new_data_key)

# %% [markdown]
# ### Seleccionar shapefiles de paises especificos
# ##### borrar carpetas en terminal / rm -rf "shapefiles2"

# %% [raw]
# if not os.path.exists('Shapefiles2'):
#     bucket_shapefiles = 'graphdata-mobility-public'
#     folder_local = 'Shapefiles2'
#     os.mkdir(folder_local)
#     for key in s3.Bucket(bucket_shapefiles).objects.all().filter(Prefix = 'Shapefiles'): # Carpeta en bucket
#         data_key = key.key
#         directorios = data_key.split('/')
#         if len(directorios) == 3 and not 'Municipios' in data_key: # carpeta originen, pais y archivo (shp, cpg, csv, dbf, prj, shx)
#             folder_pais = os.path.join(folder_local, directorios[1])
#             if directorios[1] in ['PE', 'UY', 'PY']:
#                 if not os.path.exists(folder_pais):
#                     os.mkdir(folder_pais)
#                 new_data_key = os.path.join(folder_pais,directorios[2])
#                 s3.Bucket(bucket_shapefiles).download_file(data_key, new_data_key)

# %% [markdown]
# ### Actualización deltas -  Aca comienza el flujo

# %%
fecha_inicio = '09-01-2020'
fecha_final = '09-30-2020'
fechas = pd.date_range(fecha_inicio, fecha_final)

# %%
historico_hogares = f'historico_hogares'
for fecha in fechas:
    start_time_day = time.time()
    day = str(fecha.day)
    if len(day) == 1:
        day = f'0{day}'
    codigo_fecha = str(fecha.month) + day
    print(codigo_fecha)
    
    
    # Generando tabla temporal de coordenadas de hogates
    # ==============================
    todos_usuarios_delta = f'todos_usuarios_delta_dist_corregida_{codigo_fecha}'
    print(todos_usuarios_delta)
    starttime=time.time()
    query = f'''SELECT delta.lat_final as lat_hogar,
                       delta.long_final as long_hogar,
                       delta.iso_country_code  
                FROM (SELECT filtro.caid, 
                             filtro.n_obs, 
                             filtro.lat_final, 
                             filtro.long_final, 
                             t2.id_provincia, 
                             t2.provincia, 
                             filtro.year, 
                             filtro.month, 
                             filtro.day, 
                             filtro.iso_country_code 
                     FROM {todos_usuarios_delta} AS filtro 
                     LEFT JOIN (SELECT ROUND(lat_hogar,3) AS lat_hogar2, 
                                       ROUND(long_hogar,3) AS long_hogar2, 
                                       id_provincia, 
                                       provincia, 
                                       iso_country_code 
                                FROM {historico_hogares} 
                                GROUP BY ROUND(lat_hogar,3),
                                         ROUND(long_hogar,3),
                                         id_provincia,
                                         provincia,
                                         iso_country_code) AS t2  
                    ON filtro.lat_final=t2.lat_hogar2 
                    AND filtro.long_final=t2.long_hogar2 
                    AND filtro.iso_country_code=t2.iso_country_code) AS delta 
                WHERE delta.id_provincia IS NULL 
                GROUP BY delta.lat_final,
                         delta.long_final,
                         delta.iso_country_code'''
    df_usuario_coord = cursor.execute(query).as_pandas()    
    print(f"Tiempo query select: {int((time.time()-starttime))}s")
    print(f"Tamaño tabla sin id_provincia en historico: {df_usuario_coord.shape[0]}")
    #assert df_usuario_coord[df_usuario_coord.duplicated(['long_hogar','lat_hogar','iso_country_code'])].shape[0] == 0
    
    
    # Asignando region a la tabla hogares por dia
    # ==============================
    starttime=time.time()
    paises = ['AR','CO','PE','NI','SV','BO','DO','CL','CR','PY','BZ','HN','JM','TT','UY','GY','EC','GT','PA','VE',"BR","MX"]
    for pais in paises:
        print(f"Pais: {pais}")
        df_usuario_coord2 = df_usuario_coord.loc[df_usuario_coord["iso_country_code"]==pais]
        print(df_usuario_coord2.shape)
        gdf_homes = gpd.GeoDataFrame(df_usuario_coord2,
                                     geometry=gpd.points_from_xy(
                                         df_usuario_coord2.long_hogar, 
                                         df_usuario_coord2.lat_hogar), 
                                         crs = 'epsg:4326')
        gdf_homes = gdf_homes.dropna(subset=['long_hogar','lat_hogar'])
        path = glob.glob(f'Shapefiles/{pais}/*.shp')
        mapa = gpd.read_file(path[0],encoding = 'utf-8')
        mapa = mapa.to_crs("epsg:4326")
        if pais == "CL":
            mapa = mapa.loc[:,['codregion', 'Region', 'geometry']]
            gdf_homes = gpd.sjoin(gdf_homes, mapa, op='within') 
            gdf_homes=gdf_homes.loc[:,['long_hogar','lat_hogar','codregion', 'Region','iso_country_code']]
            gdf_homes=gdf_homes.rename(columns={"codregion":"id_provincia",'Region': 'Provincia'})
            gdf_homes=gdf_homes.dropna(subset=["id_provincia"])
        if pais == "CR":       
            mapa = mapa.loc[:,['COD_PROV', 'NPROVINCIA', 'geometry']]
            gdf_homes = gpd.sjoin(gdf_homes, mapa, op='within') 
            gdf_homes=gdf_homes.loc[:,['long_hogar','lat_hogar','COD_PROV', 'NPROVINCIA','iso_country_code']]
            gdf_homes=gdf_homes.rename(columns={"COD_PROV":"id_provincia",'NPROVINCIA': 'Provincia'})
            gdf_homes=gdf_homes.dropna(subset=["id_provincia"])
        if ((pais != "CR") & (pais != "CL")):
            mapa = mapa.loc[:,["ID_1",'NAME_1','geometry']]
            gdf_homes = gpd.sjoin(gdf_homes, mapa, op='within') 
            gdf_homes=gdf_homes.loc[:,['long_hogar','lat_hogar',"ID_1",'NAME_1','iso_country_code']]
            gdf_homes=gdf_homes.rename(columns={"ID_1":"id_provincia",'NAME_1': 'Provincia'})
            gdf_homes=gdf_homes.dropna(subset=["id_provincia"])
        if pais == 'AR':
            base_nuevos=gdf_homes
        else:
            base_nuevos=base_nuevos.append(gdf_homes) 
    #df a nivel nacion   
    print(f"Asociar id_provincia a hogares: {int(time.time()-starttime)}s")
    
    
    # Creando tabla hogares final por dia
    # ==============================
    starttime = time.time()
    wr.s3.to_parquet(  # Storing the data and metadata to Data Lake
        df=base_nuevos,
        dataset=True,
        table=f"base_nuevos_{codigo_fecha}",
        database="graphdata",
        dtype={'Provincia': 'string'},
        path=f"s3://iadbprod-csd-hub-analyticaldata/graphdata-mobility-temporal/Tablas_hogares/Tablas_hogares_final/base_nuevos_{codigo_fecha}"
    )
    print(f"Guardar tabla base_nuevos_dia:{int((time.time()-starttime))}s")    
    
    
    # Creando tabla historica a nivel de hogares
    # ==============================
    starttime = time.time()
    historico_hogares = f'historico_hogares'
    tabla_hogares_fecha = f'base_nuevos_{codigo_fecha}'
    if codigo_fecha == '201': 
        # CREAR TABLA
        query = f'''CREATE TABLE {historico_hogares} 
            WITH (    
             external_location = 's3://iadbprod-csd-hub-analyticaldata/graphdata-mobility-usuarios/{historico_hogares}',  
             format = 'PARQUET', 
             parquet_compression = 'SNAPPY') AS 
            SELECT *
            FROM {tabla_hogares_fecha}  '''
        cursor.execute(query)
    else:
        # INSERTAR
        query = f'''INSERT INTO {historico_hogares} SELECT * FROM {tabla_hogares_fecha} '''
        cursor.execute(query) 
    print(f"Tiempo total dia {fecha}: {int(time.time() - start_time_day)}s")
    print("*"*90)
    query = (f"MSCK REPAIR TABLE historico_hogares")
    cursor.execute(query) 
    time.sleep(60)
    
    
    # Creando tabla usuarios final por dia
    # ==============================
    starttime=time.time()
    tabla_final_usuario_dia = f'usuarios_final_{codigo_fecha}'
    query = f'''CREATE TABLE {tabla_final_usuario_dia} 
         WITH (    
         external_location = 's3://iadbprod-csd-hub-analyticaldata/graphdata-mobility-temporal/Tablas_usuarios/Usuarios_final/{tabla_final_usuario_dia}',  
         format = 'PARQUET', 
         parquet_compression = 'SNAPPY') AS 
         SELECT filtro.caid,
                filtro.year,
                filtro.month,
                filtro.day,
                filtro.distancia_recorrida,
                filtro.n_obs,
                filtro.n_obs_noche,
                filtro.n_obs_madrugada,
                filtro.lat_hogar,
                filtro.long_hogar,
                filtro.n_obs_hogar,
                filtro.lat_mas_visitado,
                filtro.long_mas_visitado,
                filtro.n_obs_mas_visitado,
                filtro.lat_frecuente,
                filtro.long_frecuente,
                filtro.lat_final,
                filtro.long_final,
                t2.id_provincia, 
                t2.provincia,
                filtro.iso_country_code
        FROM {todos_usuarios_delta} AS filtro 
            LEFT JOIN (SELECT ROUND(lat_hogar,3) AS lat_hogar2, 
                              ROUND(long_hogar,3) AS long_hogar2, 
                              id_provincia, 
                              provincia, 
                              iso_country_code 
                       FROM historico_hogares 
                       GROUP BY ROUND(lat_hogar,3),
                                ROUND(long_hogar,3),
                                id_provincia,
                                provincia,
                                iso_country_code) AS t2  
            ON filtro.lat_final=t2.lat_hogar2 
            AND filtro.long_final=t2.long_hogar2 
            AND filtro.iso_country_code=t2.iso_country_code'''
    cursor.execute(query) 
    print(f"Crear tabla final del dia con hogares e id_provincia: {int((time.time()-starttime))}s")
    time.sleep(60)
    
    
    # Creando tabla historico a nivel de usuarios
    # ==============================
    historico_usuarios = f'historico_usuarios'
    if codigo_fecha == '201': 
        # CREAR TABLA
        query = f'''CREATE TABLE {historico_usuarios} 
            WITH (    
             external_location = 's3://iadbprod-csd-hub-analyticaldata/graphdata-mobility-usuarios/{historico_usuarios}',  
             format = 'PARQUET', 
             parquet_compression = 'SNAPPY',
             partitioned_by = ARRAY['iso_country_code']) AS 
            SELECT *
            FROM {tabla_final_usuario_dia} '''
        cursor.execute(query)
    else:
        # INSERTAR
        query = f'''INSERT INTO {historico_usuarios} SELECT * FROM {tabla_final_usuario_dia} '''
        cursor.execute(query) 
    print(f"Tiempo total dia {fecha}: {int(time.time() - start_time_day)}s")
    print("*"*90)
# Out:
# 901
# todos_usuarios_delta_dist_corregida_901
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 228551
# Pais: AR
# (31413, 3)
# Pais: CO
# (12933, 3)
# Pais: PE
# (4350, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (1684, 3)
# Pais: BO
# (4257, 3)
# Pais: DO
# (2288, 3)
# Pais: CL
# (13618, 3)
# Pais: CR
# (1560, 3)
# Pais: PY
# (3202, 3)
# Pais: BZ
# (232, 3)
# Pais: HN
# (2225, 3)
# Pais: JM
# (3409, 3)
# Pais: TT
# (1568, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (464, 3)
# Pais: EC
# (4476, 3)
# Pais: GT
# (2639, 3)
# Pais: PA
# (1214, 3)
# Pais: VE
# (3028, 3)
# Pais: BR
# (99604, 3)
# Pais: MX
# (34387, 3)
# Asociar id_provincia a hogares: 21s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-01 00:00:00: 32s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 16s
# Tiempo total dia 2020-09-01 00:00:00: 193s
# ******************************************************************************************
# 902
# todos_usuarios_delta_dist_corregida_902
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 105122
# Pais: AR
# (8976, 3)
# Pais: CO
# (5904, 3)
# Pais: PE
# (3397, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (1288, 3)
# Pais: BO
# (3321, 3)
# Pais: DO
# (1768, 3)
# Pais: CL
# (5341, 3)
# Pais: CR
# (1044, 3)
# Pais: PY
# (2143, 3)
# Pais: BZ
# (109, 3)
# Pais: HN
# (1775, 3)
# Pais: JM
# (2296, 3)
# Pais: TT
# (906, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (671, 3)
# Pais: EC
# (3167, 3)
# Pais: GT
# (2659, 3)
# Pais: PA
# (669, 3)
# Pais: VE
# (2052, 3)
# Pais: BR
# (40563, 3)
# Pais: MX
# (17073, 3)
# Asociar id_provincia a hogares: 15s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-02 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 11s
# Tiempo total dia 2020-09-02 00:00:00: 178s
# ******************************************************************************************
# 903
# todos_usuarios_delta_dist_corregida_903
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 108443
# Pais: AR
# (11370, 3)
# Pais: CO
# (7451, 3)
# Pais: PE
# (3507, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (1155, 3)
# Pais: BO
# (2453, 3)
# Pais: DO
# (1539, 3)
# Pais: CL
# (7289, 3)
# Pais: CR
# (1043, 3)
# Pais: PY
# (1603, 3)
# Pais: BZ
# (75, 3)
# Pais: HN
# (1245, 3)
# Pais: JM
# (2000, 3)
# Pais: TT
# (729, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (453, 3)
# Pais: EC
# (2352, 3)
# Pais: GT
# (2257, 3)
# Pais: PA
# (335, 3)
# Pais: VE
# (1870, 3)
# Pais: BR
# (41621, 3)
# Pais: MX
# (18096, 3)
# Asociar id_provincia a hogares: 15s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-03 00:00:00: 25s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 13s
# Tiempo total dia 2020-09-03 00:00:00: 184s
# ******************************************************************************************
# 904
# todos_usuarios_delta_dist_corregida_904
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 105321
# Pais: AR
# (11265, 3)
# Pais: CO
# (7386, 3)
# Pais: PE
# (3320, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (671, 3)
# Pais: BO
# (1840, 3)
# Pais: DO
# (1064, 3)
# Pais: CL
# (7068, 3)
# Pais: CR
# (876, 3)
# Pais: PY
# (1151, 3)
# Pais: BZ
# (36, 3)
# Pais: HN
# (935, 3)
# Pais: JM
# (1544, 3)
# Pais: TT
# (696, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (466, 3)
# Pais: EC
# (1659, 3)
# Pais: GT
# (1506, 3)
# Pais: PA
# (335, 3)
# Pais: VE
# (1646, 3)
# Pais: BR
# (46292, 3)
# Pais: MX
# (15565, 3)
# Asociar id_provincia a hogares: 15s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-04 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 8s
# Tiempo total dia 2020-09-04 00:00:00: 178s
# ******************************************************************************************
# 905
# todos_usuarios_delta_dist_corregida_905
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 105772
# Pais: AR
# (9595, 3)
# Pais: CO
# (7215, 3)
# Pais: PE
# (3284, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (516, 3)
# Pais: BO
# (1933, 3)
# Pais: DO
# (1001, 3)
# Pais: CL
# (6396, 3)
# Pais: CR
# (849, 3)
# Pais: PY
# (1111, 3)
# Pais: BZ
# (20, 3)
# Pais: HN
# (959, 3)
# Pais: JM
# (1643, 3)
# Pais: TT
# (562, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (362, 3)
# Pais: EC
# (1533, 3)
# Pais: GT
# (1618, 3)
# Pais: PA
# (392, 3)
# Pais: VE
# (1455, 3)
# Pais: BR
# (50008, 3)
# Pais: MX
# (15320, 3)
# Asociar id_provincia a hogares: 15s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-05 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 8s
# Tiempo total dia 2020-09-05 00:00:00: 178s
# ******************************************************************************************
# 906
# todos_usuarios_delta_dist_corregida_906
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 100267
# Pais: AR
# (8813, 3)
# Pais: CO
# (6098, 3)
# Pais: PE
# (2698, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (403, 3)
# Pais: BO
# (1974, 3)
# Pais: DO
# (1021, 3)
# Pais: CL
# (5665, 3)
# Pais: CR
# (683, 3)
# Pais: PY
# (1249, 3)
# Pais: BZ
# (28, 3)
# Pais: HN
# (701, 3)
# Pais: JM
# (1370, 3)
# Pais: TT
# (559, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (422, 3)
# Pais: EC
# (1495, 3)
# Pais: GT
# (1359, 3)
# Pais: PA
# (467, 3)
# Pais: VE
# (1351, 3)
# Pais: BR
# (50626, 3)
# Pais: MX
# (13285, 3)
# Asociar id_provincia a hogares: 14s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-06 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 8s
# Tiempo total dia 2020-09-06 00:00:00: 176s
# ******************************************************************************************
# 907
# todos_usuarios_delta_dist_corregida_907
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 87393
# Pais: AR
# (7838, 3)
# Pais: CO
# (5626, 3)
# Pais: PE
# (3063, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (555, 3)
# Pais: BO
# (1705, 3)
# Pais: DO
# (1053, 3)
# Pais: CL
# (5322, 3)
# Pais: CR
# (705, 3)
# Pais: PY
# (1177, 3)
# Pais: BZ
# (18, 3)
# Pais: HN
# (742, 3)
# Pais: JM
# (1410, 3)
# Pais: TT
# (541, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (387, 3)
# Pais: EC
# (1448, 3)
# Pais: GT
# (1288, 3)
# Pais: PA
# (488, 3)
# Pais: VE
# (1428, 3)
# Pais: BR
# (40588, 3)
# Pais: MX
# (12011, 3)
# Asociar id_provincia a hogares: 14s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-07 00:00:00: 23s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 11s
# Tiempo total dia 2020-09-07 00:00:00: 179s
# ******************************************************************************************
# 908
# todos_usuarios_delta_dist_corregida_908
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 74593
# Pais: AR
# (6879, 3)
# Pais: CO
# (5268, 3)
# Pais: PE
# (2819, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (540, 3)
# Pais: BO
# (1681, 3)
# Pais: DO
# (1012, 3)
# Pais: CL
# (4762, 3)
# Pais: CR
# (570, 3)
# Pais: PY
# (1237, 3)
# Pais: BZ
# (26, 3)
# Pais: HN
# (780, 3)
# Pais: JM
# (1405, 3)
# Pais: TT
# (529, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (336, 3)
# Pais: EC
# (1439, 3)
# Pais: GT
# (1122, 3)
# Pais: PA
# (491, 3)
# Pais: VE
# (1323, 3)
# Pais: BR
# (31565, 3)
# Pais: MX
# (10809, 3)
# Asociar id_provincia a hogares: 13s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-08 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 9s
# Tiempo total dia 2020-09-08 00:00:00: 177s
# ******************************************************************************************
# 909
# todos_usuarios_delta_dist_corregida_909
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 77283
# Pais: AR
# (6479, 3)
# Pais: CO
# (4213, 3)
# Pais: PE
# (2949, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (655, 3)
# Pais: BO
# (2652, 3)
# Pais: DO
# (1168, 3)
# Pais: CL
# (3921, 3)
# Pais: CR
# (543, 3)
# Pais: PY
# (1040, 3)
# Pais: BZ
# (24, 3)
# Pais: HN
# (764, 3)
# Pais: JM
# (1270, 3)
# Pais: TT
# (380, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (287, 3)
# Pais: EC
# (1722, 3)
# Pais: GT
# (962, 3)
# Pais: PA
# (715, 3)
# Pais: VE
# (1407, 3)
# Pais: BR
# (33314, 3)
# Pais: MX
# (12818, 3)
# Asociar id_provincia a hogares: 13s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-09 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 12s
# Tiempo total dia 2020-09-09 00:00:00: 183s
# ******************************************************************************************
# 910
# todos_usuarios_delta_dist_corregida_910
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 87438
# Pais: AR
# (6950, 3)
# Pais: CO
# (5301, 3)
# Pais: PE
# (3709, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (666, 3)
# Pais: BO
# (2200, 3)
# Pais: DO
# (1001, 3)
# Pais: CL
# (4334, 3)
# Pais: CR
# (563, 3)
# Pais: PY
# (1082, 3)
# Pais: BZ
# (35, 3)
# Pais: HN
# (626, 3)
# Pais: JM
# (1223, 3)
# Pais: TT
# (318, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (198, 3)
# Pais: EC
# (1759, 3)
# Pais: GT
# (1032, 3)
# Pais: PA
# (605, 3)
# Pais: VE
# (1419, 3)
# Pais: BR
# (40301, 3)
# Pais: MX
# (14116, 3)
# Asociar id_provincia a hogares: 14s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-10 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 12s
# Tiempo total dia 2020-09-10 00:00:00: 180s
# ******************************************************************************************
# 911
# todos_usuarios_delta_dist_corregida_911
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 86991
# Pais: AR
# (7308, 3)
# Pais: CO
# (4974, 3)
# Pais: PE
# (3214, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (522, 3)
# Pais: BO
# (1554, 3)
# Pais: DO
# (933, 3)
# Pais: CL
# (4580, 3)
# Pais: CR
# (558, 3)
# Pais: PY
# (1133, 3)
# Pais: BZ
# (19, 3)
# Pais: HN
# (537, 3)
# Pais: JM
# (1111, 3)
# Pais: TT
# (337, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (107, 3)
# Pais: EC
# (1998, 3)
# Pais: GT
# (1228, 3)
# Pais: PA
# (567, 3)
# Pais: VE
# (1410, 3)
# Pais: BR
# (41317, 3)
# Pais: MX
# (13584, 3)
# Asociar id_provincia a hogares: 14s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-11 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 8s
# Tiempo total dia 2020-09-11 00:00:00: 321s
# ******************************************************************************************
# 912
# todos_usuarios_delta_dist_corregida_912
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 72079
# Pais: AR
# (5495, 3)
# Pais: CO
# (4164, 3)
# Pais: PE
# (2533, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (366, 3)
# Pais: BO
# (1505, 3)
# Pais: DO
# (931, 3)
# Pais: CL
# (3612, 3)
# Pais: CR
# (622, 3)
# Pais: PY
# (999, 3)
# Pais: BZ
# (21, 3)
# Pais: HN
# (640, 3)
# Pais: JM
# (933, 3)
# Pais: TT
# (371, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (206, 3)
# Pais: EC
# (1609, 3)
# Pais: GT
# (912, 3)
# Pais: PA
# (476, 3)
# Pais: VE
# (1042, 3)
# Pais: BR
# (33234, 3)
# Pais: MX
# (12408, 3)
# Asociar id_provincia a hogares: 13s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-12 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 10s
# Tiempo total dia 2020-09-12 00:00:00: 175s
# ******************************************************************************************
# 913
# todos_usuarios_delta_dist_corregida_913
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 52811
# Pais: AR
# (4463, 3)
# Pais: CO
# (2886, 3)
# Pais: PE
# (1526, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (339, 3)
# Pais: BO
# (1482, 3)
# Pais: DO
# (716, 3)
# Pais: CL
# (2367, 3)
# Pais: CR
# (445, 3)
# Pais: PY
# (730, 3)
# Pais: BZ
# (13, 3)
# Pais: HN
# (349, 3)
# Pais: JM
# (710, 3)
# Pais: TT
# (191, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (165, 3)
# Pais: EC
# (1130, 3)
# Pais: GT
# (752, 3)
# Pais: PA
# (295, 3)
# Pais: VE
# (768, 3)
# Pais: BR
# (24714, 3)
# Pais: MX
# (8770, 3)
# Asociar id_provincia a hogares: 12s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-13 00:00:00: 22s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 7s
# Tiempo total dia 2020-09-13 00:00:00: 180s
# ******************************************************************************************
# 914
# todos_usuarios_delta_dist_corregida_914
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 48519
# Pais: AR
# (3387, 3)
# Pais: CO
# (3358, 3)
# Pais: PE
# (2511, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (411, 3)
# Pais: BO
# (939, 3)
# Pais: DO
# (708, 3)
# Pais: CL
# (2469, 3)
# Pais: CR
# (423, 3)
# Pais: PY
# (544, 3)
# Pais: BZ
# (10, 3)
# Pais: HN
# (347, 3)
# Pais: JM
# (680, 3)
# Pais: TT
# (174, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (174, 3)
# Pais: EC
# (984, 3)
# Pais: GT
# (898, 3)
# Pais: PA
# (339, 3)
# Pais: VE
# (724, 3)
# Pais: BR
# (21225, 3)
# Pais: MX
# (8214, 3)
# Asociar id_provincia a hogares: 12s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-14 00:00:00: 22s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 7s
# Tiempo total dia 2020-09-14 00:00:00: 169s
# ******************************************************************************************
# 915
# todos_usuarios_delta_dist_corregida_915
# Tiempo query select: 7s
# Tamaño tabla sin id_provincia en historico: 38367
# Pais: AR
# (2399, 3)
# Pais: CO
# (2372, 3)
# Pais: PE
# (1549, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (353, 3)
# Pais: BO
# (734, 3)
# Pais: DO
# (580, 3)
# Pais: CL
# (1859, 3)
# Pais: CR
# (308, 3)
# Pais: PY
# (582, 3)
# Pais: BZ
# (11, 3)
# Pais: HN
# (376, 3)
# Pais: JM
# (343, 3)
# Pais: TT
# (161, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (169, 3)
# Pais: EC
# (968, 3)
# Pais: GT
# (745, 3)
# Pais: PA
# (296, 3)
# Pais: VE
# (634, 3)
# Pais: BR
# (17950, 3)
# Pais: MX
# (5978, 3)
# Asociar id_provincia a hogares: 11s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-15 00:00:00: 23s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 13s
# Tiempo total dia 2020-09-15 00:00:00: 183s
# ******************************************************************************************
# 916
# todos_usuarios_delta_dist_corregida_916
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 30655
# Pais: AR
# (1575, 3)
# Pais: CO
# (2103, 3)
# Pais: PE
# (1672, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (366, 3)
# Pais: BO
# (958, 3)
# Pais: DO
# (592, 3)
# Pais: CL
# (1419, 3)
# Pais: CR
# (354, 3)
# Pais: PY
# (549, 3)
# Pais: BZ
# (15, 3)
# Pais: HN
# (428, 3)
# Pais: JM
# (442, 3)
# Pais: TT
# (169, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (136, 3)
# Pais: EC
# (979, 3)
# Pais: GT
# (754, 3)
# Pais: PA
# (253, 3)
# Pais: VE
# (538, 3)
# Pais: BR
# (11802, 3)
# Pais: MX
# (5551, 3)
# Asociar id_provincia a hogares: 11s
# Guardar tabla base_nuevos_dia:2s
# Tiempo total dia 2020-09-16 00:00:00: 22s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 11s
# Tiempo total dia 2020-09-16 00:00:00: 176s
# ******************************************************************************************
# 917
# todos_usuarios_delta_dist_corregida_917
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 27737
# Pais: AR
# (1611, 3)
# Pais: CO
# (1963, 3)
# Pais: PE
# (1800, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (333, 3)
# Pais: BO
# (909, 3)
# Pais: DO
# (441, 3)
# Pais: CL
# (1610, 3)
# Pais: CR
# (257, 3)
# Pais: PY
# (443, 3)
# Pais: BZ
# (14, 3)
# Pais: HN
# (340, 3)
# Pais: JM
# (356, 3)
# Pais: TT
# (124, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (128, 3)
# Pais: EC
# (851, 3)
# Pais: GT
# (674, 3)
# Pais: PA
# (141, 3)
# Pais: VE
# (461, 3)
# Pais: BR
# (10536, 3)
# Pais: MX
# (4745, 3)
# Asociar id_provincia a hogares: 11s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-17 00:00:00: 19s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 9s
# Tiempo total dia 2020-09-17 00:00:00: 170s
# ******************************************************************************************
# 918
# todos_usuarios_delta_dist_corregida_918
# Tiempo query select: 4s
# Tamaño tabla sin id_provincia en historico: 19712
# Pais: AR
# (1277, 3)
# Pais: CO
# (964, 3)
# Pais: PE
# (735, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (214, 3)
# Pais: BO
# (754, 3)
# Pais: DO
# (300, 3)
# Pais: CL
# (912, 3)
# Pais: CR
# (138, 3)
# Pais: PY
# (376, 3)
# Pais: BZ
# (8, 3)
# Pais: HN
# (208, 3)
# Pais: JM
# (419, 3)
# Pais: TT
# (89, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (81, 3)
# Pais: EC
# (540, 3)
# Pais: GT
# (329, 3)
# Pais: PA
# (90, 3)
# Pais: VE
# (216, 3)
# Pais: BR
# (8989, 3)
# Pais: MX
# (3073, 3)
# Asociar id_provincia a hogares: 10s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-18 00:00:00: 18s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 10s
# Tiempo total dia 2020-09-18 00:00:00: 173s
# ******************************************************************************************
# 919
# todos_usuarios_delta_dist_corregida_919
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 21610
# Pais: AR
# (998, 3)
# Pais: CO
# (947, 3)
# Pais: PE
# (671, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (193, 3)
# Pais: BO
# (686, 3)
# Pais: DO
# (302, 3)
# Pais: CL
# (646, 3)
# Pais: CR
# (155, 3)
# Pais: PY
# (435, 3)
# Pais: BZ
# (11, 3)
# Pais: HN
# (219, 3)
# Pais: JM
# (349, 3)
# Pais: TT
# (225, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (45, 3)
# Pais: EC
# (536, 3)
# Pais: GT
# (575, 3)
# Pais: PA
# (201, 3)
# Pais: VE
# (521, 3)
# Pais: BR
# (8746, 3)
# Pais: MX
# (5149, 3)
# Asociar id_provincia a hogares: 10s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-19 00:00:00: 20s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 7s
# Tiempo total dia 2020-09-19 00:00:00: 167s
# ******************************************************************************************
# 920
# todos_usuarios_delta_dist_corregida_920
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 34126
# Pais: AR
# (1865, 3)
# Pais: CO
# (1211, 3)
# Pais: PE
# (1239, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (342, 3)
# Pais: BO
# (579, 3)
# Pais: DO
# (445, 3)
# Pais: CL
# (1081, 3)
# Pais: CR
# (230, 3)
# Pais: PY
# (608, 3)
# Pais: BZ
# (15, 3)
# Pais: HN
# (310, 3)
# Pais: JM
# (276, 3)
# Pais: TT
# (282, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (39, 3)
# Pais: EC
# (828, 3)
# Pais: GT
# (746, 3)
# Pais: PA
# (294, 3)
# Pais: VE
# (784, 3)
# Pais: BR
# (14775, 3)
# Pais: MX
# (8177, 3)
# Asociar id_provincia a hogares: 11s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-20 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 7s
# Tiempo total dia 2020-09-20 00:00:00: 171s
# ******************************************************************************************
# 921
# todos_usuarios_delta_dist_corregida_921
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 52351
# Pais: AR
# (3065, 3)
# Pais: CO
# (2570, 3)
# Pais: PE
# (2632, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (591, 3)
# Pais: BO
# (1084, 3)
# Pais: DO
# (1058, 3)
# Pais: CL
# (2281, 3)
# Pais: CR
# (455, 3)
# Pais: PY
# (1035, 3)
# Pais: BZ
# (6, 3)
# Pais: HN
# (551, 3)
# Pais: JM
# (839, 3)
# Pais: TT
# (319, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (186, 3)
# Pais: EC
# (1084, 3)
# Pais: GT
# (981, 3)
# Pais: PA
# (433, 3)
# Pais: VE
# (1014, 3)
# Pais: BR
# (23536, 3)
# Pais: MX
# (8631, 3)
# Asociar id_provincia a hogares: 12s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-21 00:00:00: 22s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 7s
# Tiempo total dia 2020-09-21 00:00:00: 169s
# ******************************************************************************************
# 922
# todos_usuarios_delta_dist_corregida_922
# Tiempo query select: 7s
# Tamaño tabla sin id_provincia en historico: 63572
# Pais: AR
# (3173, 3)
# Pais: CO
# (4223, 3)
# Pais: PE
# (4159, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (730, 3)
# Pais: BO
# (1567, 3)
# Pais: DO
# (1151, 3)
# Pais: CL
# (2886, 3)
# Pais: CR
# (551, 3)
# Pais: PY
# (1054, 3)
# Pais: BZ
# (27, 3)
# Pais: HN
# (896, 3)
# Pais: JM
# (1194, 3)
# Pais: TT
# (287, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (264, 3)
# Pais: EC
# (1443, 3)
# Pais: GT
# (1718, 3)
# Pais: PA
# (559, 3)
# Pais: VE
# (1175, 3)
# Pais: BR
# (25551, 3)
# Pais: MX
# (10964, 3)
# Asociar id_provincia a hogares: 13s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-22 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 7s
# Tiempo total dia 2020-09-22 00:00:00: 175s
# ******************************************************************************************
# 923
# todos_usuarios_delta_dist_corregida_923
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 59350
# Pais: AR
# (2931, 3)
# Pais: CO
# (3532, 3)
# Pais: PE
# (3472, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (567, 3)
# Pais: BO
# (1734, 3)
# Pais: DO
# (1170, 3)
# Pais: CL
# (2640, 3)
# Pais: CR
# (421, 3)
# Pais: PY
# (1045, 3)
# Pais: BZ
# (18, 3)
# Pais: HN
# (805, 3)
# Pais: JM
# (1204, 3)
# Pais: TT
# (274, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (242, 3)
# Pais: EC
# (1452, 3)
# Pais: GT
# (1541, 3)
# Pais: PA
# (516, 3)
# Pais: VE
# (1129, 3)
# Pais: BR
# (24895, 3)
# Pais: MX
# (9762, 3)
# Asociar id_provincia a hogares: 13s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-23 00:00:00: 23s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 11s
# Tiempo total dia 2020-09-23 00:00:00: 176s
# ******************************************************************************************
# 924
# todos_usuarios_delta_dist_corregida_924
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 58960
# Pais: AR
# (3208, 3)
# Pais: CO
# (3270, 3)
# Pais: PE
# (3465, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (595, 3)
# Pais: BO
# (1980, 3)
# Pais: DO
# (1171, 3)
# Pais: CL
# (2504, 3)
# Pais: CR
# (480, 3)
# Pais: PY
# (939, 3)
# Pais: BZ
# (6, 3)
# Pais: HN
# (691, 3)
# Pais: JM
# (1079, 3)
# Pais: TT
# (286, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (208, 3)
# Pais: EC
# (1256, 3)
# Pais: GT
# (1473, 3)
# Pais: PA
# (558, 3)
# Pais: VE
# (1083, 3)
# Pais: BR
# (25003, 3)
# Pais: MX
# (9705, 3)
# Asociar id_provincia a hogares: 12s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-24 00:00:00: 23s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 12s
# Tiempo total dia 2020-09-24 00:00:00: 179s
# ******************************************************************************************
# 925
# todos_usuarios_delta_dist_corregida_925
# Tiempo query select: 8s
# Tamaño tabla sin id_provincia en historico: 62084
# Pais: AR
# (3253, 3)
# Pais: CO
# (3454, 3)
# Pais: PE
# (3490, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (575, 3)
# Pais: BO
# (1888, 3)
# Pais: DO
# (1214, 3)
# Pais: CL
# (2484, 3)
# Pais: CR
# (558, 3)
# Pais: PY
# (971, 3)
# Pais: BZ
# (5, 3)
# Pais: HN
# (746, 3)
# Pais: JM
# (1155, 3)
# Pais: TT
# (312, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (201, 3)
# Pais: EC
# (1374, 3)
# Pais: GT
# (1347, 3)
# Pais: PA
# (555, 3)
# Pais: VE
# (1110, 3)
# Pais: BR
# (26901, 3)
# Pais: MX
# (10491, 3)
# Asociar id_provincia a hogares: 12s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-25 00:00:00: 25s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 12s
# Tiempo total dia 2020-09-25 00:00:00: 180s
# ******************************************************************************************
# 926
# todos_usuarios_delta_dist_corregida_926
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 66976
# Pais: AR
# (3498, 3)
# Pais: CO
# (3465, 3)
# Pais: PE
# (2173, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (565, 3)
# Pais: BO
# (1836, 3)
# Pais: DO
# (962, 3)
# Pais: CL
# (2830, 3)
# Pais: CR
# (659, 3)
# Pais: PY
# (1135, 3)
# Pais: BZ
# (4, 3)
# Pais: HN
# (737, 3)
# Pais: JM
# (1158, 3)
# Pais: TT
# (275, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (185, 3)
# Pais: EC
# (1809, 3)
# Pais: GT
# (1108, 3)
# Pais: PA
# (530, 3)
# Pais: VE
# (1089, 3)
# Pais: BR
# (32488, 3)
# Pais: MX
# (10470, 3)
# Asociar id_provincia a hogares: 13s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-26 00:00:00: 23s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 11s
# Tiempo total dia 2020-09-26 00:00:00: 177s
# ******************************************************************************************
# 927
# todos_usuarios_delta_dist_corregida_927
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 62258
# Pais: AR
# (3665, 3)
# Pais: CO
# (3386, 3)
# Pais: PE
# (2748, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (515, 3)
# Pais: BO
# (1709, 3)
# Pais: DO
# (997, 3)
# Pais: CL
# (2809, 3)
# Pais: CR
# (643, 3)
# Pais: PY
# (824, 3)
# Pais: BZ
# (7, 3)
# Pais: HN
# (777, 3)
# Pais: JM
# (1154, 3)
# Pais: TT
# (251, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (128, 3)
# Pais: EC
# (1658, 3)
# Pais: GT
# (1450, 3)
# Pais: PA
# (503, 3)
# Pais: VE
# (1117, 3)
# Pais: BR
# (28161, 3)
# Pais: MX
# (9756, 3)
# Asociar id_provincia a hogares: 13s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-27 00:00:00: 24s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 12s
# Tiempo total dia 2020-09-27 00:00:00: 178s
# ******************************************************************************************
# 928
# todos_usuarios_delta_dist_corregida_928
# Tiempo query select: 6s
# Tamaño tabla sin id_provincia en historico: 55544
# Pais: AR
# (3147, 3)
# Pais: CO
# (3477, 3)
# Pais: PE
# (2999, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (524, 3)
# Pais: BO
# (1444, 3)
# Pais: DO
# (797, 3)
# Pais: CL
# (2742, 3)
# Pais: CR
# (632, 3)
# Pais: PY
# (755, 3)
# Pais: BZ
# (6, 3)
# Pais: HN
# (645, 3)
# Pais: JM
# (1028, 3)
# Pais: TT
# (243, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (100, 3)
# Pais: EC
# (1512, 3)
# Pais: GT
# (1426, 3)
# Pais: PA
# (509, 3)
# Pais: VE
# (1027, 3)
# Pais: BR
# (23164, 3)
# Pais: MX
# (9367, 3)
# Asociar id_provincia a hogares: 12s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-28 00:00:00: 23s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 12s
# Tiempo total dia 2020-09-28 00:00:00: 176s
# ******************************************************************************************
# 929
# todos_usuarios_delta_dist_corregida_929
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 50188
# Pais: AR
# (2665, 3)
# Pais: CO
# (3563, 3)
# Pais: PE
# (3440, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (529, 3)
# Pais: BO
# (1826, 3)
# Pais: DO
# (801, 3)
# Pais: CL
# (2313, 3)
# Pais: CR
# (539, 3)
# Pais: PY
# (916, 3)
# Pais: BZ
# (7, 3)
# Pais: HN
# (638, 3)
# Pais: JM
# (940, 3)
# Pais: TT
# (136, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (88, 3)
# Pais: EC
# (1693, 3)
# Pais: GT
# (1363, 3)
# Pais: PA
# (457, 3)
# Pais: VE
# (1005, 3)
# Pais: BR
# (19910, 3)
# Pais: MX
# (7359, 3)
# Asociar id_provincia a hogares: 12s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-29 00:00:00: 21s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 8s
# Tiempo total dia 2020-09-29 00:00:00: 173s
# ******************************************************************************************
# 930
# todos_usuarios_delta_dist_corregida_930
# Tiempo query select: 5s
# Tamaño tabla sin id_provincia en historico: 27853
# Pais: AR
# (1289, 3)
# Pais: CO
# (2204, 3)
# Pais: PE
# (2045, 3)
# Pais: NI
# (0, 3)
# Pais: SV
# (389, 3)
# Pais: BO
# (1187, 3)
# Pais: DO
# (470, 3)
# Pais: CL
# (1450, 3)
# Pais: CR
# (354, 3)
# Pais: PY
# (438, 3)
# Pais: BZ
# (2, 3)
# Pais: HN
# (411, 3)
# Pais: JM
# (556, 3)
# Pais: TT
# (71, 3)
# Pais: UY
# (0, 3)
# Pais: GY
# (74, 3)
# Pais: EC
# (1026, 3)
# Pais: GT
# (758, 3)
# Pais: PA
# (305, 3)
# Pais: VE
# (600, 3)
# Pais: BR
# (9675, 3)
# Pais: MX
# (4549, 3)
# Asociar id_provincia a hogares: 11s
# Guardar tabla base_nuevos_dia:0s
# Tiempo total dia 2020-09-30 00:00:00: 20s
# ******************************************************************************************
# Crear tabla final del dia con hogares e id_provincia: 15s
# Tiempo total dia 2020-09-30 00:00:00: 176s
# ******************************************************************************************
